# %% [markdown]
# # Basics of IBMQ
#
# ### Getting started
#
# Firstly if you want to access the IBM machines you will need to sign up at [https://quantum-computing.ibm.com/](https://quantum-computing.ibm.com/).
#
# Once signed up you can very quickly get started with the [Quantum Composer](https://quantum-computing.ibm.com/composer). This is a drag and drop circuit composer which you can run on an actual quantum computer. (Although without additional permission you are limited to 5-7 qubits).

# %% [markdown]
# For example, I created the following circuit.
#
# ![image.png](attachment:image.png)
#
# **Question: What does the above circuit do?**
#
# After running it on the machine Quito I got the following result.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Quantum architectures -- creating highly entangled states

# %% [markdown]
# Suppose I want to create the 5 qubit entangled state
# $$
# |\psi\rangle = \frac{|00000\rangle + |11111\rangle}{\sqrt{2}}\,.
# $$
# The first section of the following circuit should work
#
# ![image.png](attachment:image.png)
#
#
# Now I try to run it on the Quito machine. However, before it runs it will translate the circuit into the following equivalent circuit
#
# ![image-2.png](attachment:image-2.png)
#
# **Why is this equivalent and why is this happening?**

# %% [markdown]
# Well if we look at the details of the Quito machine [link](https://quantum-computing.ibm.com/services/resources?system=ibmq_quito).
#
# ![image.png](attachment:image.png)
#
# We see that there is a restriction on the "connectivity" of the qubits. We can't implement a CNOT between any two qubits.Thus the system transforms the circuit into one that it can impement.
#
# **Question: what's the minimum number of CNOTS required given the architecture?**
#
# ![image-2.png](attachment:image-2.png)
#
# We see the results seem to be quite noisy. Could you design a more efficient implementation by reducing the number of CNOTs?
